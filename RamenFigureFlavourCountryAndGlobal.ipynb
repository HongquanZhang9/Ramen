# %%
import matplotlib.pyplot as plt
topFlavours = {
    'chicken': 325,
    'seafood': 265,
    'beef': 233,
    'pork': 101,
    'mushroom': 48,
    
}

topSeasonings = {
    'spicy': 388,
    'curry': 127,
    'oriental': 57,
    'tonkotsu': 53,
    'thai': 35
}

countryFlavour = {'USA': {'chicken': 92, 'seafood': 35, 'beef': 40, 'pork': 7, 'mushroom': 8}, 
                  'China': {'chicken': 16, 'seafood': 18, 'beef': 50, 'pork': 21, 'mushroom': 7}, 
                  'Japan': {'chicken': 10, 'seafood': 18, 'beef': 3, 'pork': 10, 'mushroom': 2}, 
                  'Hong Kong': {'chicken': 16, 'seafood': 26, 'beef': 19, 'pork': 9, 'mushroom': 2}, 
                  'Indonesia': {'chicken': 25, 'seafood': 2, 'beef': 5, 'pork': 0, 'mushroom': 1},
                  'Vietnam': {'chicken': 21, 'seafood': 25, 'beef': 13, 'pork': 11, 'mushroom': 7}, 
                  'Thailand': {'chicken': 15, 'seafood': 51, 'beef': 13, 'pork': 22, 'mushroom': 3}, 
                  'Taiwan': {'chicken': 14, 'seafood': 11, 'beef': 25, 'pork': 18, 'mushroom': 5}, 
                  'South Korea': {'chicken': 12, 'seafood': 34, 'beef': 20, 'pork': 2, 'mushroom': 2}, 
                  'Singapore': {'chicken': 13, 'seafood': 17, 'beef': 6, 'pork': 0, 'mushroom': 4}, 
                  'Malaysia': {'chicken': 9, 'seafood': 4, 'beef': 0, 'pork': 0, 'mushroom': 2}}

countrySeasonings = {'USA': {'spicy': 75, 'curry': 5, 'oriental': 4, 'tonkotsu': 9, 'thai': 12}, 
                     'China': {'spicy': 63, 'curry': 0, 'oriental': 0, 'tonkotsu': 0, 'thai': 0}, 
                     'Japan': {'spicy': 17, 'curry': 16, 'oriental': 4, 'tonkotsu': 30, 'thai': 0}, 
                     'Hong Kong': {'spicy': 24, 'curry': 5, 'oriental': 0, 'tonkotsu': 13, 'thai': 0}, 
                     'Indonesia': {'spicy': 10, 'curry': 3, 'oriental': 0, 'tonkotsu': 0, 'thai': 0}, 
                     'Vietnam': {'spicy': 12, 'curry': 1, 'oriental': 2, 'tonkotsu': 0, 'thai': 5}, 
                     'Thailand': {'spicy': 15, 'curry': 3, 'oriental': 16, 'tonkotsu': 1, 'thai': 4}, 
                     'Taiwan': {'spicy': 40, 'curry': 5, 'oriental': 3, 'tonkotsu': 0, 'thai': 0}, 
                     'South Korea': {'spicy': 52, 'curry': 5, 'oriental': 2, 'tonkotsu': 0, 'thai': 0}, 
                     'Singapore': {'spicy': 21, 'curry': 12, 'oriental': 3, 'tonkotsu': 0, 'thai': 2}, 
                     'Malaysia': {'spicy': 14, 'curry': 48, 'oriental': 3, 'tonkotsu': 0, 'thai': 1}}


countryVariety = {   
    'Japan': 352,
    'USA': 323,
    'South Korea': 309,
    'Taiwan': 224,
    'Thailand': 191,
    'China': 169,
    'Malaysia': 156,
    'Hong Kong': 137,
    'Indonesia': 126,
    'Singapore': 109,
    'Vietnam': 108,    
}

# %%
name_list = list(countryVariety.keys())
num_list = list(countryVariety.values())
plt.barh(range(len(num_list)), num_list,color='rgb',tick_label=name_list)
plt.title('Top 11 Countries with The Most Varieties')
plt.show()

# %%
name_list = list(topFlavours.keys())
num_list = list(topFlavours.values())
plt.barh(range(len(num_list)), num_list,color='rgb',tick_label=name_list)
plt.title('Global Top Five Flavours')
plt.show()

# %%
for flavour in topFlavours.keys():
    name_list = list(countryFlavour.keys())
    num_list = [v[flavour] for v in countryFlavour.values()]
    plt.barh(range(len(num_list)), num_list,color='rgb',tick_label=name_list)
    plt.title('Preference of '+flavour)
    plt.show()

# %%
name_list = list(topSeasonings.keys())
num_list = list(topSeasonings.values())
plt.barh(range(len(num_list)), num_list,color='rgb',tick_label=name_list)
plt.title('Global Top Five Seasonings')
plt.show()

# %%
for seasoning in topSeasonings.keys():
    name_list = list(countrySeasonings.keys())
    num_list = [v[seasoning] for v in countrySeasonings.values()]
    plt.barh(range(len(num_list)), num_list,color='rgb',tick_label=name_list)
    plt.title('Preference of '+seasoning)
    plt.show()

# %% [markdown]
# top three countries love chicken are: USA, Indonesia, Vietnam
# top three countries love seafood are: Thailand, USA, South Korea
# top ... beef are: China, USA, Taiwan
# top ... pork are: Thailand, China, Taiwan
# top ... mushroom: USA, China, Vietnam
#
# Will the global flavour trend reflects to each country?
# No. As the figures above.
#
# One of interesting countries is Japan, though Japan owns the most of the variety of ramens, it seems that it is not interested in the base five popular flavoures. From the data, we find that Japan has lots of special local flavours, and the number of variety of the flavours beats the number of some global leading flavours.
#
# FOr the seasonings, we find an interesting point, that is, each country almost has its own dominant seasonings. For example, In the global five popular seasonings, Ramen produced in China only occupies the part of spicy, while the others are 0.
