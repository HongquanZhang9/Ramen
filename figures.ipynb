# %%
import global_and_country_preference as gcp
# Out:
# {'USA': {'spicy': 75, 'curry': 5, 'oriental': 4, 'tonkotsu': 9, 'thai': 12}, 'China': {'spicy': 63, 'curry': 0, 'oriental': 0, 'tonkotsu': 0, 'thai': 0}, 'Japan': {'spicy': 17, 'curry': 16, 'oriental': 4, 'tonkotsu': 30, 'thai': 0}, 'Hong Kong': {'spicy': 24, 'curry': 5, 'oriental': 0, 'tonkotsu': 13, 'thai': 0}, 'Indonesia': {'spicy': 10, 'curry': 3, 'oriental': 0, 'tonkotsu': 0, 'thai': 0}, 'Vietnam': {'spicy': 12, 'curry': 1, 'oriental': 2, 'tonkotsu': 0, 'thai': 5}, 'Thailand': {'spicy': 15, 'curry': 3, 'oriental': 16, 'tonkotsu': 1, 'thai': 4}, 'Taiwan': {'spicy': 40, 'curry': 5, 'oriental': 3, 'tonkotsu': 0, 'thai': 0}, 'South Korea': {'spicy': 52, 'curry': 5, 'oriental': 2, 'tonkotsu': 0, 'thai': 0}, 'Singapore': {'spicy': 21, 'curry': 12, 'oriental': 3, 'tonkotsu': 0, 'thai': 2}, 'Malaysia': {'spicy': 14, 'curry': 48, 'oriental': 3, 'tonkotsu': 0, 'thai': 1}}

# %%
#plot figures used in the slide P13 and P14
gcp.plotFigures()
# Out:
# /Users/hongquanzhang/PycharmProjects/RamenProject/global_and_country_preference.py:47: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   plt.barh(range(len(num_list)), num_list,color='rgb',tick_label=name_list)
# /Users/hongquanzhang/PycharmProjects/RamenProject/global_and_country_preference.py:56: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   plt.barh(range(len(num_list)), num_list,color='rgb',tick_label=name_list)
# /Users/hongquanzhang/PycharmProjects/RamenProject/global_and_country_preference.py:66: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   plt.barh(range(len(num_list)), num_list,color='rgb',tick_label=name_list)
# ...
